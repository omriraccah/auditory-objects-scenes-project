# %% [markdown]
# # One-subject auditory ROI beta analysis

# %%
import os
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
from nilearn.image import load_img, resample_to_img
from nilearn.masking import apply_mask
from nilearn import plotting

# %%
# -----------------------------
# User parameters
# -----------------------------

SAVE_DIR = "/gpfs/milgram/project/turk-browne/aa2842/auditory-objects-scenes-project/GLM/results"
PREPROC_DIR = "/gpfs/milgram/scratch60/turk-browne/aa2842/sandbox/auditory-object-scenes-data/preprocessed"
SUBJECT = "pp06"
TASK = "audlocalizer"
SPACE = "T1w"

HARVARD_OXFORD_ROI_DIR = os.path.join(PREPROC_DIR, f"sub-{SUBJECT}", "rois", "harvard-oxford")
ASHS_ROI_DIR = os.path.join(
    PREPROC_DIR, f"sub-{SUBJECT}", "rois", "ASHS_maguire", "final",
    "func_masks", "bin_masks_5B_T1"
)

# Edit these dictionaries to change the analyzed ROIs.
HARVARD_OXFORD_ROIS = {
    "PPA": "Parahippocampal Gyrus, posterior division.nii.gz",  # PHG
    "LOC": "Lateral Occipital Cortex, superior division.nii.gz",  # OPA
    "HG": "Heschl's Gyrus (includes H1 and H2).nii.gz",
    "STG_A": "Superior Temporal Gyrus, anterior division.nii.gz",
    "STG_P": "Superior Temporal Gyrus, posterior division.nii.gz",
}

# Bilateral/whole ASHS masks only; left and right masks are intentionally omitted.
ASHS_ROIS = {
    "DG": "combined_dentate_gyrus_mask_T1.nii.gz",
    "CA2_3": "combined_ca_2_3_mask_T1.nii.gz",
    "CA1": "combined_ca_1_mask_T1.nii.gz",
    "Subiculum": "combined_subiculum_mask_T1.nii.gz",
    "Uncus": "combined_uncus_mask_T1.nii.gz",
    "PreParasubiculum": "combined_pre_parasubiculum_mask_T1.nii.gz",
    "HPC": "combined_HPC_mask_T1.nii.gz",
}

ROIS = {
    **{code: os.path.join(HARVARD_OXFORD_ROI_DIR, name) for code, name in HARVARD_OXFORD_ROIS.items()},
    **{code: os.path.join(ASHS_ROI_DIR, name) for code, name in ASHS_ROIS.items()},
}

CONDITIONS = {
    "Scenes": "auditory_scene",
    "Objects": "auditory_object",
    "Scrambled scenes": "auditory_scrambled_scene",
}

MASK_THRESHOLD = 0
OUTPUT_DIR = os.path.join(SAVE_DIR, "first_level_glm", f"sub-{SUBJECT}", "roi_beta_analysis")
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
def format_subject(sub):
    sub = str(sub).strip().replace("sub-", "")
    if not sub.startswith("pp"):
        sub = f"pp{sub}"
    return sub


def condition_effect_path(condition_id):
    sub_bids = f"sub-{format_subject(SUBJECT)}"
    return os.path.join(
        SAVE_DIR,
        "first_level_glm",
        sub_bids,
        "condition",
        condition_id,
        f"{sub_bids}_task-{TASK}_condition-{condition_id}_space-{SPACE}_desc-fixedEffects_stat-effect_size.nii.gz",
    )


def roi_mask_path(roi_file_name):
    if os.path.isabs(roi_file_name):
        return roi_file_name
    if not (roi_file_name.endswith(".nii") or roi_file_name.endswith(".nii.gz")):
        roi_file_name = f"{roi_file_name}.nii.gz"
    return os.path.join(ROI_MASK_DIR, roi_file_name)


def make_binary_mask(mask_img, threshold=0):
    mask_data = mask_img.get_fdata()
    mask_data = np.isfinite(mask_data) & (mask_data > threshold)
    return nib.Nifti1Image(mask_data.astype(np.uint8), mask_img.affine, mask_img.header)


def extract_mean_beta(beta_img, roi_path, threshold=0):
    roi_img = load_img(roi_path)
    roi_img = resample_to_img(roi_img, beta_img, interpolation="nearest", force_resample=True, copy_header=True)
    roi_img = make_binary_mask(roi_img, threshold=threshold)

    values = apply_mask(beta_img, roi_img)
    values = values[np.isfinite(values)]

    if values.size == 0:
        raise ValueError(f"No finite voxels found in ROI mask: {roi_path}")

    return float(np.mean(values)), int(values.size)

# %%
rows = []
condition_paths = {label: condition_effect_path(condition_id) for label, condition_id in CONDITIONS.items()}
roi_paths = {code: roi_mask_path(file_name) for code, file_name in ROIS.items()}
missing_paths = [path for path in [*condition_paths.values(), *roi_paths.values()] if not os.path.isfile(path)]
if missing_paths:
    raise FileNotFoundError("Missing required GLM or ROI files:\n" + "\n".join(missing_paths))

condition_imgs = {label: load_img(path) for label, path in condition_paths.items()}

for roi_code, roi_file_name in ROIS.items():
    roi_path = roi_paths[roi_code]

    for condition_label, beta_img in condition_imgs.items():
        mean_beta, n_voxels = extract_mean_beta(
            beta_img,
            roi_path,
            threshold=MASK_THRESHOLD,
        )

        rows.append({
            "roi": roi_code,
            "roi_name": os.path.basename(roi_file_name),
            "condition": condition_label,
            "mean_beta": mean_beta,
            "n_voxels": n_voxels,
            "roi_path": roi_path,
        })

results = pd.DataFrame(rows)
results
# Out:
#                  roi                                           roi_name  \
# 0                PPA   Parahippocampal Gyrus, posterior division.nii.gz
# 1                PPA   Parahippocampal Gyrus, posterior division.nii.gz
# 2                PPA   Parahippocampal Gyrus, posterior division.nii.gz
# 3                LOC  Lateral Occipital Cortex, superior division.ni...
# 4                LOC  Lateral Occipital Cortex, superior division.ni...
# 5                LOC  Lateral Occipital Cortex, superior division.ni...
# 6                 HG         Heschl's Gyrus (includes H1 and H2).nii.gz
# 7                 HG         Heschl's Gyrus (includes H1 and H2).nii.gz
# 8                 HG         Heschl's Gyrus (includes H1 and H2).nii.gz
# 9              STG_A  Superior Temporal Gyrus, anterior division.nii.gz
# 10             STG_A  Superior Temporal Gyrus, anterior division.nii.gz
# 11             STG_A  Superior Temporal Gyrus, anterior division.nii.gz
# 12             STG_P  Superior Temporal Gyrus, posterior division.ni...
# 13             STG_P  Superior Temporal Gyrus, posterior division.ni...
# 14             STG_P  Superior Temporal Gyrus, posterior division.ni...
# 15                DG              combined_dentate_gyrus_mask_T1.nii.gz
# 16                DG              combined_dentate_gyrus_mask_T1.nii.gz
# 17                DG              combined_dentate_gyrus_mask_T1.nii.gz
# 18             CA2_3                     combined_ca_2_3_mask_T1.nii.gz
# 19             CA2_3                     combined_ca_2_3_mask_T1.nii.gz
# 20             CA2_3                     combined_ca_2_3_mask_T1.nii.gz
# 21               CA1                       combined_ca_1_mask_T1.nii.gz
# 22               CA1                       combined_ca_1_mask_T1.nii.gz
# 23               CA1                       combined_ca_1_mask_T1.nii.gz
# 24         Subiculum                  combined_subiculum_mask_T1.nii.gz
# 25         Subiculum                  combined_subiculum_mask_T1.nii.gz
# 26         Subiculum                  combined_subiculum_mask_T1.nii.gz
# 27             Uncus                      combined_uncus_mask_T1.nii.gz
# 28             Uncus                      combined_uncus_mask_T1.nii.gz
# 29             Uncus                      combined_uncus_mask_T1.nii.gz
# 30  PreParasubiculum          combined_pre_parasubiculum_mask_T1.nii.gz
# 31  PreParasubiculum          combined_pre_parasubiculum_mask_T1.nii.gz
# 32  PreParasubiculum          combined_pre_parasubiculum_mask_T1.nii.gz
# 33               HPC                        combined_HPC_mask_T1.nii.gz
# 34               HPC                        combined_HPC_mask_T1.nii.gz
# 35               HPC                        combined_HPC_mask_T1.nii.gz
#
#            condition  mean_beta  n_voxels  \
# 0             Scenes  -0.016668      1207
# 1            Objects  -0.012164      1207
# 2   Scrambled scenes  -0.002585      1207
# 3             Scenes  -0.093059     16900
# 4            Objects  -0.148124     16900
# 5   Scrambled scenes  -0.087229     16900
# 6             Scenes   0.951847      1032
# 7            Objects   0.891215      1032
# 8   Scrambled scenes   0.471593      1032
# 9             Scenes   0.329037       997
# 10           Objects   0.272677       997
# 11  Scrambled scenes   0.111237       997
# 12            Scenes  -0.058614      1449
# 13           Objects  -0.054331      1449
# 14  Scrambled scenes  -0.132563      1449
# 15            Scenes  -0.008108       321
# 16           Objects  -0.051517       321
# 17  Scrambled scenes  -0.023207       321
# 18            Scenes  -0.002737        67
# 19           Objects   0.054730        67
# 20  Scrambled scenes   0.015537        67
# 21            Scenes   0.031137       495
# 22           Objects   0.045440       495
# 23  Scrambled scenes   0.035669       495
# 24            Scenes  -0.023348       320
# 25           Objects  -0.025585       320
# 26  Scrambled scenes  -0.019717       320
# 27            Scenes   0.067019       227
# 28           Objects   0.052109       227
# 29  Scrambled scenes   0.038627       227
# 30            Scenes  -0.157983        95
# 31           Objects  -0.171548        95
# 32  Scrambled scenes  -0.172280        95
# 33            Scenes   0.002562      1527
# 34           Objects  -0.002759      1527
# 35  Scrambled scenes  -0.002282      1527
#
#                                              roi_path
# 0   /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 1   /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 2   /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 3   /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 4   /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 5   /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 6   /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 7   /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 8   /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 9   /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 10  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 11  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 12  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 13  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 14  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 15  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 16  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 17  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 18  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 19  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 20  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 21  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 22  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 23  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 24  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 25  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 26  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 27  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 28  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 29  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 30  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 31  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 32  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 33  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 34  /gpfs/milgram/scratch60/turk-browne/aa2842/san...
# 35  /gpfs/milgram/scratch60/turk-browne/aa2842/san...

# %%
csv_path = os.path.join(OUTPUT_DIR, f"sub-{format_subject(SUBJECT)}_task-{TASK}_roi_condition_betas.csv")
results.to_csv(csv_path, index=False)
print(f"Saved CSV: {csv_path}")
# Out:
# Saved CSV: /gpfs/milgram/project/turk-browne/aa2842/auditory-objects-scenes-project/GLM/results/first_level_glm/sub-pp06/roi_beta_analysis/sub-pp06_task-audlocalizer_roi_condition_betas.csv

# %%
plot_df = results.pivot(index="roi", columns="condition", values="mean_beta")
plot_df = plot_df[[c for c in CONDITIONS.keys() if c in plot_df.columns]]

ax = plot_df.plot(kind="bar", figsize=(max(7, 0.8 * len(plot_df)), 4), width=0.75)
ax.axhline(0, linewidth=0.8)
ax.set_xlabel("")
ax.set_ylabel("Mean beta / effect size")
ax.set_title(f"sub-{format_subject(SUBJECT)} auditory localizer ROI responses")
ax.legend(title="")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

fig_path = os.path.join(OUTPUT_DIR, f"sub-{format_subject(SUBJECT)}_task-{TASK}_panelB_roi_barplot.png")
plt.savefig(fig_path, dpi=200)
plt.show()

#print(f"Saved figure: {fig_path}")

# %%
roi_code = "PPA"

plotting.plot_roi(
    roi_mask_path(ROIS[roi_code]),
    bg_img=os.path.join(PREPROC_DIR, f"sub-{format_subject(SUBJECT)}", "anat", f"sub-{format_subject(SUBJECT)}_desc-preproc_T1w.nii.gz"),
    title=f"{format_subject(SUBJECT)} {roi_code}: {os.path.basename(ROIS[roi_code])}",
    display_mode="ortho")
